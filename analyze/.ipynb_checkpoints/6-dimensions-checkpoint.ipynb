# %%
import pandas as pd

# %%
df = pd.read_csv('../data/6-dimensions-for-website-2015-08-16.csv', header=0)

# %%
df
# Out:
#      ctr              country     pdi     idv     mas     uai  ltowvs     ivr
# 0    AFE          Africa East      64      27      41      52      32      40
# 1    AFW          Africa West      77      20      46      54       9      78
# 2    ALB              Albania  #NULL!  #NULL!  #NULL!  #NULL!      61      15
# 3    ALG              Algeria  #NULL!  #NULL!  #NULL!  #NULL!      26      32
# 4    AND              Andorra  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!      65
# 5    ARA       Arab countries      80      38      53      68      23      34
# 6    ARG            Argentina      49      46      56      86      20      62
# 7    ARM              Armenia  #NULL!  #NULL!  #NULL!  #NULL!      61  #NULL!
# 8    AUL            Australia      38      90      61      51      21      71
# 9    AUT              Austria      11      55      79      70      60      63
# 10   AZE           Azerbaijan  #NULL!  #NULL!  #NULL!  #NULL!      61      22
# ...

# %%
df["mas_rank"] = df["mas"].rank(method='min',ascending=False)

# %%
df["pdi_rank"] = df["pdi"].rank(method='min',ascending=False)

# %%
df.to_csv('6-dimensions.csv')
