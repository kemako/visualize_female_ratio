# %%
import pandas as pd

# %%
df = pd.read_csv('../data/internet_female.csv', header=2)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Economy name', 'Unnamed: 2', 'year', 'Individuals',
#        'Unnamed: 5', 'Male', 'Unnamed: 7', 'Female', 'Unnamed: 9'],
#       dtype='object')

# %%
df["rank"] = df["Female"].rank(method='min',ascending=False)

# %%
df
# Out:
#     Unnamed: 0                                       Economy name  \
# 0          NaN                                          Argentina
# 1          NaN                                            Armenia
# 2          NaN                                          Australia
# 3          NaN                                            Austria
# 4          NaN                                         Azerbaijan
# 5          NaN                                            Bahrain
# 6          NaN                                         Bangladesh
# 7          NaN                                            Belarus
# 8          NaN                                            Belgium
# 9          NaN                                            Bolivia
# 10         NaN                                           Botswana
# 11         NaN                                             Brazil
# 12         NaN                                  Brunei Darussalam
# ...

# %%
df.to_csv('internet_female.csv')
#df_new.to_csv('female_ratio_information.csv')
#df_new.to_csv('female_ratio_science.csv')
#df_new.to_csv('female_ratio_agriculture.csv')
