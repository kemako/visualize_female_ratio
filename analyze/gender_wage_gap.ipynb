# %%
import pandas as pd

# %%
df = pd.read_csv('../data/gender_wage_gap.csv', header=0)

# %%
df.shape
# Out:
# (1006, 8)

# %%
df
# Out:
#      LOCATION INDICATOR       SUBJECT MEASURE FREQUENCY  TIME      Value  \
# 0         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1975  21.582734
# 1         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1976  20.754717
# 2         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1977  18.390805
# 3         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1978  19.791667
# 4         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1979  20.000000
# 5         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1980  18.750000
# 6         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1981  18.253968
# 7         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1982  20.819113
# 8         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1983  19.155844
# 9         AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1984  18.674699
# 10        AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1985  19.607843
# 11        AUS   WAGEGAP      EMPLOYEE  PC_PNT         A  1986  18.848168
# ...

# %%
df_tmp = df.drop_duplicates(subset=['LOCATION'], keep='last')

# %%
df_tmp.shape
# Out:
# (46, 8)

# %%
df_tmp.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
df_tmp.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
df_new = df_tmp.drop(['INDICATOR', 'MEASURE', 'Flag Codes'], axis=1)

# %%
df_new2 = df_new[df_new["SUBJECT"] == "EMPLOYEE"]

# %%
df_new2
# Out:
#      LOCATION   SUBJECT FREQUENCY  TIME      Value
# 40        AUS  EMPLOYEE         A  2016  14.286311
# 70        AUT  EMPLOYEE         A  2016  15.670900
# 100       BEL  EMPLOYEE         A  2015   4.672000
# 129       CAN  EMPLOYEE         A  2016  18.221154
# 161       CZE  EMPLOYEE         A  2017  15.614011
# 176       DNK  EMPLOYEE         A  2016   5.732628
# 227       FIN  EMPLOYEE         A  2016  16.472258
# 244       FRA  EMPLOYEE         A  2014   9.872102
# 270       DEU  EMPLOYEE         A  2016  15.510719
# 293       GRC  EMPLOYEE         A  2016   4.485050
# 330       HUN  EMPLOYEE         A  2016   9.364317
# 353       ISL  EMPLOYEE         A  2015   9.931403
# 382       IRL  EMPLOYEE         A  2016  10.611735
# 407       ITA  EMPLOYEE         A  2016   5.555556
# 450       JPN  EMPLOYEE         A  2017  24.518093
# 477       KOR  EMPLOYEE         A  2017  34.617383
# 493       LUX  EMPLOYEE         A  2014   3.402917
# ...

# %%
df_tertiary = pd.read_csv('../data/female_ratio_tertiary.csv', header=0)

# %%
df_tertiary=df_tertiary[["Country","LOCATION"]]

# %%
df_tertiary
# Out:
#                        Country LOCATION
# 0                     Malaysia      MYS
# 1                     Malaysia      MYS
# 2                     Malaysia      MYS
# 3                     Malaysia      MYS
# 4                     Malaysia      MYS
# 5                     Malaysia      MYS
# 6                      Liberia      LBR
# 7                      Finland      FIN
# 8                      Finland      FIN
# 9                      Finland      FIN
# 10                     Finland      FIN
# 11                     Finland      FIN
# 12                   Singapore      SGP
# 13                      Mexico      MEX
# 14                      Mexico      MEX
# 15                      Mexico      MEX
# 16                      Mexico      MEX
# 17                      Mexico      MEX
# 18                    Bulgaria      BGR
# 19                    Bulgaria      BGR
# 20                    Bulgaria      BGR
# 21                    Bulgaria      BGR
# ...

# %%
df_out =  pd.merge(df_new2, df_tertiary, on='LOCATION').drop_duplicates(subset="LOCATION")

# %%
df_out.replace(['United States of America'],[ 'United States'], inplace=True)

# %%
df_out
# Out:
#      LOCATION   SUBJECT FREQUENCY  TIME      Value  \
# 0         AUS  EMPLOYEE         A  2016  14.286311
# 22        AUT  EMPLOYEE         A  2016  15.670900
# 55        BEL  EMPLOYEE         A  2015   4.672000
# 110       CAN  EMPLOYEE         A  2016  18.221154
# 154       CZE  EMPLOYEE         A  2017  15.614011
# 209       DNK  EMPLOYEE         A  2016   5.732628
# 264       FIN  EMPLOYEE         A  2016  16.472258
# 319       FRA  EMPLOYEE         A  2014   9.872102
# 374       DEU  EMPLOYEE         A  2016  15.510719
# 418       GRC  EMPLOYEE         A  2016   4.485050
# 462       HUN  EMPLOYEE         A  2016   9.364317
# 517       ISL  EMPLOYEE         A  2015   9.931403
# 561       IRL  EMPLOYEE         A  2016  10.611735
# 612       ITA  EMPLOYEE         A  2016   5.555556
# 667       JPN  EMPLOYEE         A  2017  24.518093
# 702       KOR  EMPLOYEE         A  2017  34.617383
# 735       LUX  EMPLOYEE         A  2014   3.402917
# ...

# %%
df_out.to_csv('gender_wage.csv')
