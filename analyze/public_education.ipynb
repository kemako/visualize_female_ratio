# %%
import pandas as pd

# %%
df = pd.read_csv('../data/public_education.csv', header=4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Lower secondary ', 'Unnamed: 5', 'Upper secondary ', 'Unnamed: 7',
#        'All secondary ', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Short-cycle tertiary', 'Unnamed: 13',
#        'Bachelor's, master's and doctorate degrees', 'Unnamed: 15',
#        'All tertiary ', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Total',
#        'Unnamed: 21',
#        'Of which: public transfers and payments to the non-educational private sector',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40'],
#       dtype='object')

# %%
df_new = df.drop([ 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23','Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30','Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40'], axis=1)
df_new
# Out:
#             Unnamed: 0  Lower secondary   Upper secondary   All secondary   \
# 0            Australia               2.8               1.8             4.7
# 1              Austria               2.3               1.9             4.2
# 2              Belgium               1.6               3.4             5.0
# 3               Canada               NaN               3.6             3.6
# 4                Chile               2.1               3.6             5.7
# 5       Czech Republic               2.1               2.0             4.1
# 6              Denmark               2.2               3.3             5.5
# 7              Estonia               1.8               1.9             3.7
# 8              Finland               1.9               2.7             4.6
# 9               France               2.2               2.0             4.2
# 10             Germany               2.8               1.9             4.7
# ...

# %%
df_new.to_csv('public_education.csv')
#df_new.to_csv('female_ratio_information.csv')
#df_new.to_csv('female_ratio_science.csv')
#df_new.to_csv('female_ratio_agriculture.csv')
